# %% [markdown]
# # KRAS G12D COAD — Differential Gene Dependency & GSEA
#
# This notebook identifies genes that are differentially essential in **KRAS G12D colorectal adenocarcinoma (COAD)** cell lines compared to KRAS wild-type COAD lines, using CRISPR gene effect scores from the DepMap 24Q2 release.
#
# ## Background
#
# KRAS is the most frequently mutated oncogene in human cancer. In colorectal cancer, ~40% of tumors harbor a KRAS mutation, with G12D being the most common allele. Different KRAS alleles have distinct biochemical properties — G12D preferentially activates PI3K signaling, while G12C and G12V show stronger MAPK dependence — but whether these differences translate into allele-specific genetic vulnerabilities is not well established.
#
# DepMap's genome-wide CRISPR knockout screens (Chronos scores) measure how essential each gene is for cell viability across hundreds of cancer cell lines. A more negative score means knockout of that gene is more lethal. By comparing gene effect scores between KRAS-mutant and KRAS wild-type lines within the same cancer type, we can nominate genes that are selectively essential in the mutant context — potential therapeutic vulnerabilities.
#
# ## Approach
#
# 1. Filter DepMap cell lines to COAD and identify KRAS G12D vs. KRAS wild-type models
# 2. Run a Welch's t-test for each gene comparing mean effect scores between the two groups
# 3. Apply Benjamini-Hochberg FDR correction
# 4. Rank all genes by mean effect score in G12D lines (most essential first)
# 5. Run pre-ranked GSEA against KEGG gene sets to identify enriched biological pathways
#
# **Data:** DepMap Public 24Q2 — `CRISPRGeneEffect.csv`, `OmicsSomaticMutations.csv`, `Model.csv`
# **Data DOI:** [10.25452/figshare.plus.27993248.v1](https://doi.org/10.25452/figshare.plus.27993248.v1)

# %% [markdown]
# ## Setup
#
# Update the paths in the cell below to point to your local copies of the DepMap data files and MSigDB gene set files.
# Gene sets (KEGG, PID, BioCarta) can be downloaded from [MSigDB](https://www.gsea-msigdb.org/gsea/msigdb/).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats
import gseapy as gp
from statsmodels.stats.multitest import multipletests
from pathlib import Path

# %%
# --- Configure paths ---
# Update these to match your local data directory
DATA_DIR = Path("/path/to/DepMap")
GENESETS_DIR = Path("/path/to/genesets")

MODEL_PATH      = DATA_DIR / "Model.csv"
OSM_PATH        = DATA_DIR / "OmicsSomaticMutations.csv"
EFFECT_PATH     = DATA_DIR / "CRISPRGeneEffect.csv"
DEPENDENCY_PATH = DATA_DIR / "CRISPRGeneDependency.csv"

KEGG_GMT      = GENESETS_DIR / "c2.cp.kegg_medicus.v2026.1.Hs.symbols.gmt"
PID_GMT       = GENESETS_DIR / "c2.cp.pid.v2026.1.Hs.symbols.gmt"
BIOCARTA_GMT  = GENESETS_DIR / "c2.cp.biocarta.v2026.1.Hs.symbols.gmt"

# --- Analysis parameters ---
CANCER_TYPE = "COAD"
GENE        = "KRAS"
ALLELE      = "p.G12D"

# Output directory
REPO_ROOT  = Path().resolve().parent
OUTPUT_DIR = REPO_ROOT / "outputs"
OUTPUT_DIR.mkdir(exist_ok=True)

PVALUE_CUTOFF = 0.05
FDR_CUTOFF    = 0.25  # standard GSEA FDR threshold

# %%
# Load DepMap data
model_df      = pd.read_csv(MODEL_PATH,      header=0, index_col=0)
osm_df        = pd.read_csv(OSM_PATH,        header=0, low_memory=False)
effect_df = pd.read_csv(EFFECT_PATH, header=0)
effect_df.rename(columns={effect_df.columns[0]: 'ModelID'}, inplace=True)
effect_df.columns = ['ModelID'] + [col.split(' ')[0] for col in effect_df.columns[1:]]
dependency_df = pd.read_csv(DEPENDENCY_PATH, header=0, index_col=0)


# Load gene sets
kegg     = gp.read_gmt(path=str(KEGG_GMT))
pid      = gp.read_gmt(path=str(PID_GMT))
biocarta = gp.read_gmt(path=str(BIOCARTA_GMT))

print(f"Loaded {effect_df.shape[0]} cell lines x {effect_df.shape[1]} genes")
# Out:
# Loaded 1178 cell lines x 17917 genes

# %% [markdown]
# ## 1. Define KRAS G12D and Wild-Type Groups
#
# We restrict to COAD lines and split them into:
# - **Mutant**: cell lines carrying the specific KRAS allele of interest (G12D)
# - **WT**: COAD lines with no KRAS mutation of any kind
#
# Importantly, the WT group excludes *all* KRAS-mutant lines (not just G12D), to avoid confounding the comparison with other alleles.

# %%
# All COAD models
coad_models = model_df[model_df['OncotreeCode'] == CANCER_TYPE].copy()
coad_models = coad_models.reset_index()[['ModelID']]

# Merge with somatic mutation data to get mutations in COAD lines
osm_coad = coad_models.merge(osm_df, on='ModelID', how='inner')

# KRAS G12D mutant lines
mutant_ids = (
    osm_coad[
        (osm_coad['HugoSymbol'] == GENE) &
        (osm_coad['ProteinChange'] == ALLELE)
    ][['ModelID']]
    .drop_duplicates()
)

# All KRAS-mutant COAD lines (any allele) — excluded from WT group
all_kras_mutant_ids = (
    osm_coad[osm_coad['HugoSymbol'] == GENE][['ModelID']]
    .drop_duplicates()
)

# WT: COAD lines with no KRAS mutation
wt_ids = coad_models[
    ~coad_models['ModelID'].isin(all_kras_mutant_ids['ModelID'])
]

print(f"KRAS {ALLELE} COAD lines: {len(mutant_ids)}")
print(f"KRAS WT COAD lines:       {len(wt_ids)}")
# Out:
# KRAS p.G12D COAD lines: 11
# KRAS WT COAD lines:       39

# %%
# Merge each group with CRISPR gene effect scores
effect_mutant = mutant_ids.merge(effect_df, on='ModelID', how='inner').set_index('ModelID')
effect_wt     = wt_ids.merge(effect_df,     on='ModelID', how='inner').set_index('ModelID')

print(f"Mutant group: {effect_mutant.shape[0]} lines")
print(f"WT group:     {effect_wt.shape[0]} lines")
# Out:
# Mutant group: 5 lines
# WT group:     24 lines

# %% [markdown]
# ## 2. Differential Dependency: Welch's t-test + FDR Correction
#
# For each gene, we run a two-sample Welch's t-test comparing the CRISPR effect scores of the G12D group to the WT group. We then apply Benjamini-Hochberg correction to control the false discovery rate across ~18,000 simultaneous tests.
#
# Note that with only ~11 G12D lines, statistical power is limited — the FDR-corrected results should be interpreted as suggestive rather than definitive. The GSEA in the next section partially addresses this by aggregating signal across gene sets rather than individual genes.

# %%
# Welch's t-test for each gene
gene_columns = [col for col in effect_df.columns if col != 'ModelID']

_, p_values = scipy.stats.ttest_ind(
    effect_wt, effect_mutant,
    nan_policy='omit',
    axis=0
)

pvalue_df = pd.DataFrame({
    'gene': gene_columns,
    'p_value': p_values,
    'mean_effect_mutant': effect_mutant.mean(axis=0).values,
    'mean_effect_wt':     effect_wt.mean(axis=0).values,
}).dropna(subset=['p_value'])

# Benjamini-Hochberg FDR correction
reject, fdr_values, _, _ = multipletests(
    pvalue_df['p_value'], alpha=0.25, method='fdr_bh'
)
pvalue_df['fdr'] = fdr_values
pvalue_df['significant'] = reject

# Mean effect difference (mutant - WT); more negative = more essential in mutant
pvalue_df['effect_diff'] = pvalue_df['mean_effect_mutant'] - pvalue_df['mean_effect_wt']

pvalue_df = pvalue_df.sort_values('p_value')

sig = pvalue_df[pvalue_df['significant']]
print(f"Genes significant at FDR < 0.25: {len(sig)}")
print(f"\nTop 10 most significant:")
sig.head(10)[['gene', 'p_value', 'fdr', 'mean_effect_mutant', 'effect_diff']]
# Out:
# Genes significant at FDR < 0.25: 1
#
# Top 10 most significant:
#       gene       p_value       fdr  mean_effect_mutant  effect_diff
# 7807  KRAS  4.847237e-08  0.000868           -1.758938    -1.244659

# %% [markdown]
# ## 3. Pre-ranked GSEA
#
# Rather than only examining individual gene hits, we use Gene Set Enrichment Analysis (GSEA) to ask whether biologically coherent pathways are collectively more essential in G12D lines.
#
# We rank all genes by their **mean CRISPR effect score in the G12D group** (most essential first — most negative score at the top). GSEA then tests whether genes belonging to each KEGG pathway are non-randomly distributed toward the top (more essential) or bottom (less essential) of this ranking.
#
# A **negative enrichment score (NES < 0)** means the pathway is enriched toward the top of the ranking — i.e., those genes are more essential in G12D COAD lines.

# %%
# Build ranked gene list: all genes ranked by mean effect in G12D mutant lines
rnk = pd.DataFrame({
    'gene':   effect_mutant.columns,
    'scores': effect_mutant.mean(axis=0, skipna=True).values
})
rnk = rnk.dropna().sort_values('scores', ascending=True)

print(f"Ranked gene list: {len(rnk)} genes")
print(f"Score range: {rnk['scores'].min():.3f} to {rnk['scores'].max():.3f}")
rnk.head(10)
# Out:
# Ranked gene list: 17916 genes
# Score range: -4.555 to 0.656
#          gene    scores
# 14390  SNRPD3 -4.554986
# 12478     RAN -3.971822
# 6835    HSPE1 -3.412384
# 13034   RPL12 -3.133087
# 13134    RPS8 -3.090085
# 13042   RPL21 -3.071104
# 13115   RPS29 -3.056308
# 14384  SNRPA1 -3.023481
# 13643   SF3B5 -2.963320
# 16545    UBL5 -2.932627

# %%
# Run pre-ranked GSEA against KEGG gene sets
enr = gp.prerank(
    rnk=rnk,
    gene_sets=kegg,
    threads=4,
    min_size=10,
    max_size=500,
    permutation_num=1000,
    outdir=None,
    seed=42,
    verbose=True
)

gsea_results = enr.res2d.copy()
gsea_results = gsea_results.sort_values('NES')

# Show top negatively enriched pathways (more essential in G12D)
top_neg = gsea_results[gsea_results['FDR q-val'] < FDR_CUTOFF].head(15)
print(f"Pathways at FDR < {FDR_CUTOFF}: {len(gsea_results[gsea_results['FDR q-val'] < FDR_CUTOFF])}")
top_neg[['Term', 'NES', 'NOM p-val', 'FDR q-val', 'Tag %']]
# Out:
# 2026-06-30 21:51:16,417 [INFO] Parsing data files for GSEA.............................
# 2026-06-30 21:51:16,441 [INFO] 0264 gene_sets have been filtered out when max_size=500 and min_size=10
# 2026-06-30 21:51:16,442 [INFO] 0394 gene_sets used for further statistical testing.....
# 2026-06-30 21:51:16,443 [INFO] Start to run GSEA...Might take a while..................
# 2026-06-30 21:51:22,605 [INFO] Congratulations. GSEApy runs successfully................
# Pathways at FDR < 0.25: 89
#                                                  Term       NES  NOM p-val  \
# 2       KEGG_MEDICUS_REFERENCE_TRANSLATION_INITIATION -1.884147        0.0
# 4   KEGG_MEDICUS_REFERENCE_26S_PROTEASOME_MEDIATED... -1.806802        0.0
# 5   KEGG_MEDICUS_VARIANT_MUTATION_INACTIVATED_VCP_... -1.806516        0.0
# 6   KEGG_MEDICUS_VARIANT_MUTATION_CAUSED_ABERRANT_... -1.806197        0.0
# 7   KEGG_MEDICUS_VARIANT_SCRAPIE_CONFORMATION_PRPS... -1.801208        0.0
# ...

# %% [markdown]
# ## 4. Results
#
# ### Top negatively enriched pathways (more essential in KRAS G12D COAD)
#
# The analysis consistently identifies **ribosome biogenesis**, **proteasome**, **spliceosome**, **RNA polymerase**, and **DNA replication** as the most negatively enriched pathways — meaning genes in these core cellular machinery pathways show significantly more negative CRISPR scores in G12D lines than in WT COAD lines.
#
# This pattern is consistent with the oncogenic stress hypothesis: KRAS G12D-driven hyperproliferation places elevated demand on protein synthesis and quality control machinery, creating a heightened dependency on ribosomal and proteasomal function. The top individual gene hit, **RPS7**, encodes a small ribosomal subunit protein and also functions as a p53 activator when perturbed — a link that may be relevant in the context of colorectal cancer.
#
# Below we plot the enrichment curve for the top pathway and a dot plot of the top results.

# %%
# Enrichment plot for top pathway
top_term = gsea_results.iloc[0]['Term']
axs = enr.plot(terms=top_term)
plt.suptitle(f"Enrichment plot: {top_term}\nKRAS G12D vs WT — COAD (DepMap 24Q2)", y=1.02)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "gsea_top_pathway.png", dpi=150, bbox_inches='tight')
plt.show()
# Out:
# /var/folders/k9/bz30f50d0bv1pzq8kv4wkg4h0000gn/T/ipykernel_94531/1596210946.py:5: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
# Dot plot of top negatively enriched pathways
plot_df = gsea_results[gsea_results['FDR q-val'] < FDR_CUTOFF].head(15).copy()
plot_df = plot_df.sort_values('NES', ascending=True)

# Clean up term names for display
plot_df['Term_short'] = plot_df['Term'].str.replace('KEGG_', '').str.replace('_', ' ').str.title()

fig, ax = plt.subplots(figsize=(7, 6))

scatter = ax.scatter(
    x=plot_df['NES'],
    y=range(len(plot_df)),
    c=-np.log10(plot_df['FDR q-val'].clip(lower=1e-4)),
    cmap='Blues',
    s=80,
    edgecolors='grey',
    linewidths=0.5
)

ax.set_yticks(range(len(plot_df)))
ax.set_yticklabels(plot_df['Term_short'], fontsize=9)
ax.axvline(x=0, color='grey', linestyle='--', linewidth=0.8)
ax.set_xlabel('Normalized Enrichment Score (NES)', fontsize=11)
ax.set_title(f'GSEA: KRAS G12D vs WT — {CANCER_TYPE}\n(KEGG pathways, FDR < {FDR_CUTOFF})', fontsize=11)

cbar = plt.colorbar(scatter, ax=ax, shrink=0.6)
cbar.set_label('-log10(FDR)', fontsize=9)

plt.tight_layout()
plt.savefig(OUTPUT_DIR / "gsea_dotplot.png", dpi=150, bbox_inches='tight')
plt.show()
